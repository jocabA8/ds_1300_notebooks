# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
import geopandas
from IPython.display import display
warnings.simplefilter(action='ignore',category=FutureWarning)

# %config InlineBackend.figure_format ='retina'

# %%
df = pd.read_csv('Longitudinal Religious Congregations and Membership File, 1980-2010 (State Level).csv',delimiter=',',skipfooter=14,engine='python')

# %%
df.sort_values(by='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 1747       6      CA  2010  37253956     081
# 1559       6      CA  2000  33871648     081
# 12365     36      NY  2000  18976457     081
# 12275     36      NY  1990  17990456     081
# 1546       6      CA  1990  29760030     081
# ...      ...     ...   ...       ...     ...
# 2160       8      CO  2010   5029196     309
# 7727      24      MD  2010   5773552     454
# 13690     41      OR  2000   3421399     370
# 5325      17      IL  2010  12830632     172
# 9147      29      MO  2000   5595211     360
#
#                                                  GRPNAME    ADHERENT  CONGREG  \
# 1747                                     Catholic Church  10233334.0   1315.0
# 1559                                     Catholic Church  10079310.0   1315.0
# 12365                                    Catholic Church   7550491.0   1784.0
# 12275                                    Catholic Church   7280488.0   1874.0
# ...

# %%
#Southern Region: Alabama, Arkansas, Delaware, District Of Columbia, Florida, Georgia, Kentucky, Louisiana, Maryland, Mississippi, North Carolina, Oklahoma, South Carolina, Tennessee, Texas, Virginia, West Virginia
#Acryonyms: AL, AR, DE, DC, FL, GA, KY, LA, MD, MS, NC, OK, SC, TN, TX, VA, WV

# %%
#2010 top 5 Christian Churches - Southern Baptist Convention, Catholic Church, The United Methodist Church, old count, Churches of Christ, National Baptist Convention, USA, Inc.
#2000 top 5 Christian Churches - Southern Baptist Convention, Catholic Church, The United Methodist Church, old count, Presbyterian Church (U.S.A.), Churches of Christ 
#1990 top 5 Christian Churches - Southern Baptist Convention, Catholic Church, The United Methodist Church, old count, Black Baptists Estimate, Presbyterian Church (U.S.A.)
#1980 top 5 Christian Churches - Southern Baptist Convention, Catholic Church, The United Methodist Church, old count, Presbyterian Church (U.S.A.), Churches of Christ

# %%
#Alabama, AL:
df_AL = df[df.STATEAB == 'AL']
df_AL
#For 2010-
df_AL_2010 = df_AL[df_AL.YEAR == 2010]
df_AL_2010_2 = df_AL_2010[df_AL_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_AL_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 583      1      AL  2010  4779736     419
# 572      1      AL  2010  4779736     449
# 598      1      AL  2010  4779736     081
# 543      1      AL  2010  4779736     300
# 488      1      AL  2010  4779736     167
#
#                                     GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 583             Southern Baptist Convention  1392363.0   3324.0        1
# 572  The United Methodist Church, old count   299151.0   1274.0        2
# 598                         Catholic Church   200657.0    169.0        3
# 543  National Baptist Convention, USA, Inc.   175176.0    382.0        6
# 488                      Churches of Christ   114015.0    867.0        1
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 583    96.0         0         0         3
# 572    92.0         0         0         0
# 598    87.0         0         0         2
# 543    96.0         0         0         0
# 488   115.0         0         0         0

# %%
#For 2000-
df_AL_2000 = df_AL[df_AL.YEAR == 2000]
df_AL_2000_2 = df_AL_2000[df_AL_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_AL_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 453      1      AL  2000  4447100     419
# 457      1      AL  2000  4447100     449
# 425      1      AL  2000  4447100     081
# 468      1      AL  2000  4447100     167
#
#                                     GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 453             Southern Baptist Convention  1380121.0   3148.0        1
# 457  The United Methodist Church, old count   327734.0   1416.0        2
# 425                         Catholic Church   150647.0    168.0        3
# 468                      Churches of Christ   119049.0    895.0        1
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 453    96.0         0         0         3
# 457    92.0         0         0         0
# 425    87.0         0         0         2
# 468   115.0         0         0         0

# %%
#For 1990-
df_AL_1990 = df_AL[df_AL.YEAR == 1990]
df_AL_1990_2 = df_AL_1990[df_AL_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_AL_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 373      1      AL  1990  4040587     419
# 396      1      AL  1990  4040587     497
# 380      1      AL  1990  4040587     449
# 327      1      AL  1990  4040587     081
#
#                                     GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 373             Southern Baptist Convention  1313907.0   3065.0        1
# 396                 Black Baptists Estimate   398793.0      0.0        6
# 380  The United Methodist Church, old count   332029.0   1472.0        2
# 327                         Catholic Church   137834.0    172.0        3
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 373    96.0         0         0         3
# 396    96.0         0         0         0
# 380    92.0         0         0         0
# 327    87.0         0         0         2

# %%
#For 1980
df_AL_1980 = df_AL[df_AL.YEAR == 1980]
df_AL_1980_2 = df_AL_1980[df_AL_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_AL_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 292      1      AL  1980  3893888     419
# 323      1      AL  1980  3893888     449
# 305      1      AL  1980  3893888     167
# 294      1      AL  1980  3893888     081
#
#                                     GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 292             Southern Baptist Convention  1182018.0   3005.0        1
# 323  The United Methodist Church, old count   344790.0   1524.0        2
# 305                      Churches of Christ   113919.0    875.0        1
# 294                         Catholic Church   106123.0    169.0        3
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 292    96.0         0         0         3
# 323    92.0         0         0         0
# 305   115.0         0         0         0
# 294    87.0         0         0         2

# %%
#Arkansas, AR:
df_AR = df[df.STATEAB == 'AR']
df_AR
#For 2010-
df_AR_2010 = df_AR[df_AR.YEAR == 2010]
df_AR_2010_2 = df_AR_2010[df_AR_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_AR_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 879      5      AR  2010  2915918     419
# 928      5      AR  2010  2915918     449
# 925      5      AR  2010  2915918     081
# 895      5      AR  2010  2915918     167
# 884      5      AR  2010  2915918     300
#
#                                     GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 879             Southern Baptist Convention  661382.0   1515.0        1
# 928  The United Methodist Church, old count  167405.0    691.0        2
# 925                         Catholic Church  122662.0    126.0        3
# 895                      Churches of Christ   84635.0    721.0        1
# 884  National Baptist Convention, USA, Inc.   38559.0    105.0        6
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 879    96.0         0         0         3
# 928    92.0         0         0         0
# 925    87.0         0         0         2
# 895   115.0         0         0         0
# 884    96.0         0         0         0

# %%
#For 2000-
df_AR_2000 = df_AR[df_AR.YEAR == 2000]
df_AR_2000_2 = df_AR_2000[df_AR_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_AR_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 761      5      AR  2000  2673400     419
# 781      5      AR  2000  2673400     449
# 742      5      AR  2000  2673400     081
# 795      5      AR  2000  2673400     167
#
#                                     GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 761             Southern Baptist Convention  665307.0   1372.0        1
# 781  The United Methodist Church, old count  179383.0    747.0        2
# 742                         Catholic Church  115967.0    130.0        3
# 795                      Churches of Christ   86342.0    754.0        1
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 761    96.0         0         0         3
# 781    92.0         0         0         0
# 742    87.0         0         0         2
# 795   115.0         0         0         0

# %%
#For 1990-
df_AR_1990 = df_AR[df_AR.YEAR == 1990]
df_AR_1990_2 = df_AR_1990[df_AR_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Presbyterian Church (U.S.A.)','Black Baptists Estimate'])]
df_AR_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 707      5      AR  1990  2350725     419
# 697      5      AR  1990  2350725     449
# 693      5      AR  1990  2350725     497
# 724      5      AR  1990  2350725     081
#
#                                     GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 707             Southern Baptist Convention  617524.0   1290.0        1
# 697  The United Methodist Church, old count  197402.0    788.0        2
# 693                 Black Baptists Estimate  121542.0      0.0        6
# 724                         Catholic Church   72952.0    134.0        3
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 707    96.0         0         0         3
# 697    92.0         0         0         0
# 693    96.0         0         0         0
# 724    87.0         0         0         2

# %%
#For 1980-
df_AR_1980 = df_AR[df_AR.YEAR == 1980]
df_AR_1980_2 = df_AR_1980[df_AR_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_AR_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#      STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 646      5      AR  1980  2378488     419
# 648      5      AR  1980  2378488     449
# 667      5      AR  1980  2378488     167
# 616      5      AR  1980  2378488     081
#
#                                     GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 646             Southern Baptist Convention  522985.0   1242.0        1
# 648  The United Methodist Church, old count  214526.0    875.0        2
# 667                      Churches of Christ   90671.0    763.0        1
# 616                         Catholic Church   56911.0    122.0        3
#
#      FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 646    96.0         0         0         3
# 648    92.0         0         0         0
# 667   115.0         0         0         0
# 616    87.0         0         0         2

# %%
#Delaware, DE:
df_DE = df[df.STATEAB == 'DE']
df_DE
#For 2010-
df_DE_2010 = df_DE[df_DE.YEAR == 2010]
df_DE_2010_2 = df_DE_2010[df_DE_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_DE_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 3096     10      DE  2010  897934     081
# 3080     10      DE  2010  897934     449
# 3062     10      DE  2010  897934     419
# 3088     10      DE  2010  897934     300
# 3074     10      DE  2010  897934     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 3096                         Catholic Church  182532.0     45.0        3
# 3080  The United Methodist Church, old count   51196.0    158.0        2
# 3062             Southern Baptist Convention    7387.0     33.0        1
# 3088  National Baptist Convention, USA, Inc.    2050.0     10.0        6
# 3074                      Churches of Christ    1306.0     12.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3096    87.0         0         0         2
# 3080    92.0         0         0         0
# 3062    96.0         0         0         3
# 3088    96.0         0         0         0
# 3074   115.0         0         0         0

# %%
#For 2000-
df_DE_2000 = df_DE[df_DE.YEAR == 2000]
df_DE_2000_2 = df_DE_2000[df_DE_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_DE_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2998     10      DE  2000  783600     081
# 3003     10      DE  2000  783600     449
# 2972     10      DE  2000  783600     419
# 2987     10      DE  2000  783600     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2998                         Catholic Church  151740.0     46.0        3
# 3003  The United Methodist Church, old count   59471.0    162.0        2
# 2972             Southern Baptist Convention    6310.0     19.0        1
# 2987                      Churches of Christ    1156.0     10.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2998    87.0         0         0         2
# 3003    92.0         0         0         0
# 2972    96.0         0         0         3
# 2987   115.0         0         0         0

# %%
#For 1990-
df_DE_1990 = df_DE[df_DE.YEAR == 1990]
df_DE_1990_2 = df_DE_1990[df_DE_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_DE_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2899     10      DE  1990  666168     081
# 2887     10      DE  1990  666168     449
# 2919     10      DE  1990  666168     497
# 2901     10      DE  1990  666168     419
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2899                         Catholic Church  116341.0     45.0        3
# 2887  The United Methodist Church, old count   61091.0    169.0        2
# 2919                 Black Baptists Estimate   39514.0      0.0        6
# 2901             Southern Baptist Convention    5772.0     13.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2899    87.0         0         0         2
# 2887    92.0         0         0         0
# 2919    96.0         0         0         0
# 2901    96.0         0         0         3

# %%
#For 1980
df_DE_1980 = df_DE[df_DE.YEAR == 1980]
df_DE_1980_2 = df_DE_1980[df_DE_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_DE_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2873     10      DE  1980  594338     081
# 2870     10      DE  1980  594338     449
# 2836     10      DE  1980  594338     419
# 2830     10      DE  1980  594338     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2873                         Catholic Church  103060.0     45.0        3
# 2870  The United Methodist Church, old count   60489.0    170.0        2
# 2836             Southern Baptist Convention    4279.0      9.0        1
# 2830                      Churches of Christ    1155.0      9.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2873    87.0         0         0         2
# 2870    92.0         0         0         0
# 2836    96.0         0         0         3
# 2830   115.0         0         0         0

# %%
#District of Columbia, DC:
df_DC = df[df.STATEAB == 'DC']
df_DC
#For 2010-
df_DC_2010 = df_DC[df_DC.YEAR == 2010]
df_DC_2010_2 = df_DC_2010[df_DC_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_DC_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2775     11      DC  2010  601723     081
# 2791     11      DC  2010  601723     419
# 2789     11      DC  2010  601723     300
# 2826     11      DC  2010  601723     449
# 2803     11      DC  2010  601723     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2775                         Catholic Church   75948.0     45.0        3
# 2791             Southern Baptist Convention   26600.0     63.0        1
# 2789  National Baptist Convention, USA, Inc.   22599.0     30.0        6
# 2826  The United Methodist Church, old count   10307.0     29.0        2
# 2803                      Churches of Christ     620.0      4.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2775    87.0         0         0         2
# 2791    96.0         0         0         3
# 2789    96.0         0         0         0
# 2826    92.0         0         0         0
# 2803   115.0         0         0         0

# %%
#For 2000-
df_DC_2000 = df_DC[df_DC.YEAR == 2000]
df_DC_2000_2 = df_DC_2000[df_DC_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_DC_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2681     11      DC  2000  572059     081
# 2686     11      DC  2000  572059     419
# 2721     11      DC  2000  572059     449
# 2704     11      DC  2000  572059     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2681                         Catholic Church  160048.0     42.0        3
# 2686             Southern Baptist Convention   38852.0     49.0        1
# 2721  The United Methodist Church, old count   15313.0     33.0        2
# 2704                      Churches of Christ     630.0      4.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2681    87.0         0         0         2
# 2686    96.0         0         0         3
# 2721    92.0         0         0         0
# 2704   115.0         0         0         0

# %%
#For 1990-
df_DC_1990 = df_DC[df_DC.YEAR == 1990]
df_DC_1990_2 = df_DC_1990[df_DC_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_DC_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2661     11      DC  1990  606900     497
# 2657     11      DC  1990  606900     081
# 2666     11      DC  1990  606900     449
# 2648     11      DC  1990  606900     419
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2661                 Black Baptists Estimate  102897.0      0.0        6
# 2657                         Catholic Church   77532.0     41.0        3
# 2666  The United Methodist Church, old count   18321.0     35.0        2
# 2648             Southern Baptist Convention   17597.0     29.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2661    96.0         0         0         0
# 2657    87.0         0         0         2
# 2666    92.0         0         0         0
# 2648    96.0         0         0         3

# %%
#For 1980
df_DC_1980 = df_DC[df_DC.YEAR == 1980]
df_DC_1980_2 = df_DC_1980[df_DC_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_DC_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR  TOTPOP GRPCODE  \
# 2610     11      DC  1980  638333     081
# 2624     11      DC  1980  638333     449
# 2589     11      DC  1980  638333     419
# 2621     11      DC  1980  638333     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 2610                         Catholic Church   95794.0     44.0        3
# 2624  The United Methodist Church, old count   20888.0     35.0        2
# 2589             Southern Baptist Convention   18935.0     23.0        1
# 2621                      Churches of Christ     730.0      3.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 2610    87.0         0         0         2
# 2624    92.0         0         0         0
# 2589    96.0         0         0         3
# 2621   115.0         0         0         0

# %%
#Florida, FL:
df_FL = df[df.STATEAB == 'FL']
df_FL
#For 2010-
df_FL_2010 = df_FL[df_FL.YEAR == 2010]
df_FL_2010_2 = df_FL_2010[df_FL_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_FL_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 3449     12      FL  2010  18801310     081
# 3421     12      FL  2010  18801310     419
# 3451     12      FL  2010  18801310     449
# 3565     12      FL  2010  18801310     300
# 3485     12      FL  2010  18801310     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3449                         Catholic Church  2513839.0    547.0        3
# 3421             Southern Baptist Convention  1247345.0   2965.0        1
# 3451  The United Methodist Church, old count   390932.0    768.0        2
# 3565  National Baptist Convention, USA, Inc.   122811.0    172.0        6
# 3485                      Churches of Christ    70094.0    500.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3449    87.0         0         0         2
# 3421    96.0         0         0         3
# 3451    92.0         0         0         0
# 3565    96.0         0         0         0
# ...

# %%
#For 2000-
df_FL_2000 = df_FL[df_FL.YEAR == 2000]
df_FL_2000_2 = df_FL_2000[df_FL_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_FL_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 3358     12      FL  2000  15982378     081
# 3314     12      FL  2000  15982378     419
# 3334     12      FL  2000  15982378     449
# 3405     12      FL  2000  15982378     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3358                         Catholic Church  2596148.0    527.0        3
# 3314             Southern Baptist Convention  1292097.0   2054.0        1
# 3334  The United Methodist Church, old count   458623.0    844.0        2
# 3405                      Churches of Christ    72540.0    509.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3358    87.0         0         0         2
# 3314    96.0         0         0         3
# 3334    92.0         0         0         0
# 3405   115.0         0         0         0

# %%
#For 1990-
df_FL_1990 = df_FL[df_FL.YEAR == 1990]
df_FL_1990_2 = df_FL_1990[df_FL_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_FL_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 3275     12      FL  1990  12937926     081
# 3196     12      FL  1990  12937926     419
# 3262     12      FL  1990  12937926     497
# 3189     12      FL  1990  12937926     449
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3275                         Catholic Church  1598457.0    479.0        3
# 3196             Southern Baptist Convention  1167850.0   1741.0        1
# 3262                 Black Baptists Estimate   544592.0      0.0        6
# 3189  The United Methodist Church, old count   462174.0    849.0        2
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3275    87.0         0         0         2
# 3196    96.0         0         0         3
# 3262    96.0         0         0         0
# 3189    92.0         0         0         0

# %%
#For 1980
df_FL_1980 = df_FL[df_FL.YEAR == 1980]
df_FL_1980_2 = df_FL_1980[df_FL_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_FL_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 3118     12      FL  1980  9746324     081
# 3132     12      FL  1980  9746324     419
# 3140     12      FL  1980  9746324     449
# 3179     12      FL  1980  9746324     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3118                         Catholic Church  1353478.0    399.0        3
# 3132             Southern Baptist Convention   937719.0   1537.0        1
# 3140  The United Methodist Church, old count   426591.0    826.0        2
# 3179                      Churches of Christ    57497.0    457.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3118    87.0         0         0         2
# 3132    96.0         0         0         3
# 3140    92.0         0         0         0
# 3179   115.0         0         0         0

# %%
#Georgia, GA:
df_GA = df[df.STATEAB == 'GA']
df_GA
#For 2010-
df_GA_2010 = df_GA[df_GA.YEAR == 2010]
df_GA_2010_2 = df_GA_2010[df_GA_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_GA_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 3915     13      GA  2010  9687653     419
# 3890     13      GA  2010  9687653     449
# 3949     13      GA  2010  9687653     081
# 3956     13      GA  2010  9687653     300
# 3964     13      GA  2010  9687653     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3915             Southern Baptist Convention  1759317.0   3613.0        1
# 3890  The United Methodist Church, old count   611422.0   1550.0        2
# 3949                         Catholic Church   596384.0    185.0        3
# 3956  National Baptist Convention, USA, Inc.   172982.0    272.0        6
# 3964                      Churches of Christ    55105.0    417.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3915    96.0         0         0         3
# 3890    92.0         0         0         0
# 3949    87.0         0         0         2
# 3956    96.0         0         0         0
# ...

# %%
#For 2000-
df_GA_2000 = df_GA[df_GA.YEAR == 2000]
df_GA_2000_2 = df_GA_2000[df_GA_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_GA_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 3772     13      GA  2000  8186453     419
# 3744     13      GA  2000  8186453     449
# 3806     13      GA  2000  8186453     081
# 3777     13      GA  2000  8186453     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3772             Southern Baptist Convention  1719484.0   3233.0        1
# 3744  The United Methodist Church, old count   570674.0   1614.0        2
# 3806                         Catholic Church   374185.0    179.0        3
# 3777                      Churches of Christ    48015.0    403.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3772    96.0         0         0         3
# 3744    92.0         0         0         0
# 3806    87.0         0         0         2
# 3777   115.0         0         0         0

# %%
#For 1990-
df_GA_1990 = df_GA[df_GA.YEAR == 1990]
df_GA_1990_2 = df_GA_1990[df_GA_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_GA_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 3656     13      GA  1990  6478216     419
# 3713     13      GA  1990  6478216     497
# 3695     13      GA  1990  6478216     449
# 3688     13      GA  1990  6478216     081
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3656             Southern Baptist Convention  1582520.0   3041.0        1
# 3713                 Black Baptists Estimate   639303.0      0.0        6
# 3695  The United Methodist Church, old count   530076.0   1659.0        2
# 3688                         Catholic Church   210210.0    168.0        3
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3656    96.0         0         0         3
# 3713    96.0         0         0         0
# 3695    92.0         0         0         0
# 3688    87.0         0         0         2

# %%
#For 1980
df_GA_1980 = df_GA[df_GA.YEAR == 1980]
df_GA_1980_2 = df_GA_1980[df_GA_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_GA_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 3596     13      GA  1980  5463105     419
# 3607     13      GA  1980  5463105     449
# 3622     13      GA  1980  5463105     081
# 3645     13      GA  1980  5463105     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 3596             Southern Baptist Convention  1374905.0   2958.0        1
# 3607  The United Methodist Church, old count   488909.0   1699.0        2
# 3622                         Catholic Church   141145.0    165.0        3
# 3645                      Churches of Christ    35757.0    351.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 3596    96.0         0         0         3
# 3607    92.0         0         0         0
# 3622    87.0         0         0         2
# 3645   115.0         0         0         0

# %%
#Kentucky, KY:
df_KY = df[df.STATEAB == 'KY']
df_KY
#For 2010-
df_KY_2010 = df_KY[df_KY.YEAR == 2010]
df_KY_2010_2 = df_KY_2010[df_KY_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_KY_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6629     21      KY  2010  4339367     419
# 6647     21      KY  2010  4339367     081
# 6650     21      KY  2010  4339367     449
# 6683     21      KY  2010  4339367     167
# 6601     21      KY  2010  4339367     300
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 6629             Southern Baptist Convention  1004407.0   2520.0        1
# 6647                         Catholic Church   359783.0    308.0        3
# 6650  The United Methodist Church, old count   201691.0    914.0        2
# 6683                      Churches of Christ    57388.0    607.0        1
# 6601  National Baptist Convention, USA, Inc.    22336.0     45.0        6
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6629    96.0         0         0         3
# 6647    87.0         0         0         2
# 6650    92.0         0         0         0
# 6683   115.0         0         0         0
# ...

# %%
#For 2000-
df_KY_2000 = df_KY[df_KY.YEAR == 2000]
df_KY_2000_2 = df_KY_2000[df_KY_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_KY_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6534     21      KY  2000  4041769     419
# 6537     21      KY  2000  4041769     081
# 6542     21      KY  2000  4041769     449
# 6547     21      KY  2000  4041769     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 6534             Southern Baptist Convention  979994.0   2424.0        1
# 6537                         Catholic Church  406021.0    323.0        3
# 6542  The United Methodist Church, old count  208720.0    991.0        2
# 6547                      Churches of Christ   58602.0    621.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6534    96.0         0         0         3
# 6537    87.0         0         0         2
# 6542    92.0         0         0         0
# 6547   115.0         0         0         0

# %%
#For 1990-
df_KY_1990 = df_KY[df_KY.YEAR == 1990]
df_KY_1990_2 = df_KY_1990[df_KY_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_KY_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6448     21      KY  1990  3685296     419
# 6461     21      KY  1990  3685296     081
# 6452     21      KY  1990  3685296     449
# 6464     21      KY  1990  3685296     497
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 6448             Southern Baptist Convention  962945.0   2266.0        1
# 6461                         Catholic Church  365270.0    347.0        3
# 6452  The United Methodist Church, old count  227143.0   1060.0        2
# 6464                 Black Baptists Estimate   89939.0      0.0        6
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6448    96.0         0         0         3
# 6461    87.0         0         0         2
# 6452    92.0         0         0         0
# 6464    96.0         0         0         0

# %%
#For 1980
df_KY_1980 = df_KY[df_KY.YEAR == 1980]
df_KY_1980_2 = df_KY_1980[df_KY_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_KY_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6353     21      KY  1980  3660777     419
# 6384     21      KY  1980  3660777     081
# 6352     21      KY  1980  3660777     449
# 6343     21      KY  1980  3660777     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 6353             Southern Baptist Convention  888198.0   2194.0        1
# 6384                         Catholic Church  365277.0    331.0        3
# 6352  The United Methodist Church, old count  235801.0   1109.0        2
# 6343                      Churches of Christ   59443.0    600.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6353    96.0         0         0         3
# 6384    87.0         0         0         2
# 6352    92.0         0         0         0
# 6343   115.0         0         0         0

# %%
#Louisiana, LA:
df_LA = df[df.STATEAB == 'LA']
df_LA
#For 2010-
df_LA_2010 = df_LA[df_LA.YEAR == 2010]
df_LA_2010_2 = df_LA_2010[df_LA_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_LA_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6917     22      LA  2010  4533372     081
# 6941     22      LA  2010  4533372     419
# 6974     22      LA  2010  4533372     449
# 6964     22      LA  2010  4533372     300
# 6945     22      LA  2010  4533372     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 6917                         Catholic Church  1200900.0    564.0        3
# 6941             Southern Baptist Convention   709650.0   1607.0        1
# 6974  The United Methodist Church, old count   148852.0    501.0        2
# 6964  National Baptist Convention, USA, Inc.   113433.0    187.0        6
# 6945                      Churches of Christ    24594.0    228.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6917    87.0         0         0         2
# 6941    96.0         0         0         3
# 6974    92.0         0         0         0
# 6964    96.0         0         0         0
# ...

# %%
#For 2000-
df_LA_2000 = df_LA[df_LA.YEAR == 2000]
df_LA_2000_2 = df_LA_2000[df_LA_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_LA_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6889     22      LA  2000  4468976     081
# 6819     22      LA  2000  4468976     419
# 6865     22      LA  2000  4468976     449
# 6820     22      LA  2000  4468976     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 6889                         Catholic Church  1382603.0    625.0        3
# 6819             Southern Baptist Convention   768587.0   1435.0        1
# 6865  The United Methodist Church, old count   160153.0    547.0        2
# 6820                      Churches of Christ    25899.0    229.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6889    87.0         0         0         2
# 6819    96.0         0         0         3
# 6865    92.0         0         0         0
# 6820   115.0         0         0         0

# %%
#For 1990-
df_LA_1990 = df_LA[df_LA.YEAR == 1990]
df_LA_1990_2 = df_LA_1990[df_LA_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_LA_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6812     22      LA  1990  4219973     081
# 6762     22      LA  1990  4219973     419
# 6783     22      LA  1990  4219973     497
# 6767     22      LA  1990  4219973     449
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 6812                         Catholic Church  1369154.0    627.0        3
# 6762             Southern Baptist Convention   757639.0   1349.0        1
# 6783                 Black Baptists Estimate   386062.0      0.0        6
# 6767  The United Methodist Church, old count   172676.0    576.0        2
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6812    87.0         0         0         2
# 6762    96.0         0         0         3
# 6783    96.0         0         0         0
# 6767    92.0         0         0         0

# %%
#For 1980
df_LA_1980 = df_LA[df_LA.YEAR == 1980]
df_LA_1980_2 = df_LA_1980[df_LA_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_LA_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 6717     22      LA  1980  4205900     081
# 6744     22      LA  1980  4205900     419
# 6732     22      LA  1980  4205900     449
# 6731     22      LA  1980  4205900     167
#
#                                      GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 6717                         Catholic Church  1304084.0    589.0        3
# 6744             Southern Baptist Convention   652246.0   1316.0        1
# 6732  The United Methodist Church, old count   169328.0    590.0        2
# 6731                      Churches of Christ    22931.0    226.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 6717    87.0         0         0         2
# 6744    96.0         0         0         3
# 6732    92.0         0         0         0
# 6731   115.0         0         0         0

# %%
#Maryland, MD:
df_MD = df[df.STATEAB == 'MD']
df_MD
#For 2010-
df_MD_2010 = df_MD[df_MD.YEAR == 2010]
df_MD_2010_2 = df_MD_2010[df_MD_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_MD_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 7667     24      MD  2010  5773552     081
# 7621     24      MD  2010  5773552     449
# 7637     24      MD  2010  5773552     419
# 7708     24      MD  2010  5773552     300
# 7716     24      MD  2010  5773552     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 7667                         Catholic Church  837338.0    300.0        3
# 7621  The United Methodist Church, old count  249785.0    876.0        2
# 7637             Southern Baptist Convention  150345.0    541.0        1
# 7708  National Baptist Convention, USA, Inc.   29294.0     49.0        6
# 7716                      Churches of Christ    8651.0     50.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 7667    87.0         0         0         2
# 7621    92.0         0         0         0
# 7637    96.0         0         0         3
# 7708    96.0         0         0         0
# 7716   115.0         0         0         0

# %%
#For 2000-
df_MD_2000 = df_MD[df_MD.YEAR == 2000]
df_MD_2000_2 = df_MD_2000[df_MD_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_MD_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 7559     24      MD  2000  5296486     081
# 7587     24      MD  2000  5296486     449
# 7590     24      MD  2000  5296486     419
# 7561     24      MD  2000  5296486     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 7559                         Catholic Church  952389.0    309.0        3
# 7587  The United Methodist Church, old count  297729.0    927.0        2
# 7590             Southern Baptist Convention  142401.0    405.0        1
# 7561                      Churches of Christ    8466.0     51.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 7559    87.0         0         0         2
# 7587    92.0         0         0         0
# 7590    96.0         0         0         3
# 7561   115.0         0         0         0

# %%
#For 1990-
df_MD_1990 = df_MD[df_MD.YEAR == 1990]
df_MD_1990_2 = df_MD_1990[df_MD_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_MD_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 7478     24      MD  1990  4781468     081
# 7431     24      MD  1990  4781468     449
# 7489     24      MD  1990  4781468     497
# 7485     24      MD  1990  4781468     419
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 7478                         Catholic Church  832763.0    296.0        3
# 7431  The United Methodist Church, old count  310008.0    979.0        2
# 7489                 Black Baptists Estimate  260695.0      0.0        6
# 7485             Southern Baptist Convention  131627.0    305.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 7478    87.0         0         0         2
# 7431    92.0         0         0         0
# 7489    96.0         0         0         0
# 7485    96.0         0         0         3

# %%
#For 1980
df_MD_1980 = df_MD[df_MD.YEAR == 1980]
df_MD_1980_2 = df_MD_1980[df_MD_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_MD_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 7360     24      MD  1980  4216975     081
# 7351     24      MD  1980  4216975     449
# 7375     24      MD  1980  4216975     419
# 7409     24      MD  1980  4216975     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 7360                         Catholic Church  736361.0    292.0        3
# 7351  The United Methodist Church, old count  322099.0   1011.0        2
# 7375             Southern Baptist Convention  128411.0    268.0        1
# 7409                      Churches of Christ    5016.0     33.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 7360    87.0         0         0         2
# 7351    92.0         0         0         0
# 7375    96.0         0         0         3
# 7409   115.0         0         0         0

# %%
#Mississippi, MS:
df_MS = df[df.STATEAB == 'MS']
df_MS
#For 2010-
df_MS_2010 = df_MS[df_MS.YEAR == 2010]
df_MS_2010_2 = df_MS_2010[df_MS_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_MS_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 9563     28      MS  2010  2967297     419
# 9576     28      MS  2010  2967297     449
# 9555     28      MS  2010  2967297     081
# 9590     28      MS  2010  2967297     300
# 9556     28      MS  2010  2967297     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 9563             Southern Baptist Convention  907384.0   2149.0        1
# 9576  The United Methodist Church, old count  226053.0   1107.0        2
# 9555                         Catholic Church  112488.0    154.0        3
# 9590  National Baptist Convention, USA, Inc.   81318.0    205.0        6
# 9556                      Churches of Christ   42166.0    369.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 9563    96.0         0         0         3
# 9576    92.0         0         0         0
# 9555    87.0         0         0         2
# 9590    96.0         0         0         0
# 9556   115.0         0         0         0

# %%
#For 2000-
df_MS_2000 = df_MS[df_MS.YEAR == 2000]
df_MS_2000_2 = df_MS_2000[df_MS_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_MS_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 9503     28      MS  2000  2844658     419
# 9529     28      MS  2000  2844658     449
# 9550     28      MS  2000  2844658     081
# 9520     28      MS  2000  2844658     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 9503             Southern Baptist Convention  916440.0   2037.0        1
# 9529  The United Methodist Church, old count  240576.0   1197.0        2
# 9550                         Catholic Church  115760.0    163.0        3
# 9520                      Churches of Christ   43396.0    378.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 9503    96.0         0         0         3
# 9529    92.0         0         0         0
# 9550    87.0         0         0         2
# 9520   115.0         0         0         0

# %%
#For 1990-
df_MS_1990 = df_MS[df_MS.YEAR == 1990]
df_MS_1990_2 = df_MS_1990[df_MS_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_MS_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 9483     28      MS  1990  2573216     419
# 9439     28      MS  1990  2573216     497
# 9471     28      MS  1990  2573216     449
# 9479     28      MS  1990  2573216     081
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 9483             Southern Baptist Convention  869942.0   1977.0        1
# 9439                 Black Baptists Estimate  324272.0      0.0        6
# 9471  The United Methodist Church, old count  240325.0   1270.0        2
# 9479                         Catholic Church   94948.0    156.0        3
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 9483    96.0         0         0         3
# 9439    96.0         0         0         0
# 9471    92.0         0         0         0
# 9479    87.0         0         0         2

# %%
#For 1980
df_MS_1980 = df_MS[df_MS.YEAR == 1980]
df_MS_1980_2 = df_MS_1980[df_MS_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_MS_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#       STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 9408     28      MS  1980  2520638     419
# 9412     28      MS  1980  2520638     449
# 9387     28      MS  1980  2520638     081
# 9399     28      MS  1980  2520638     167
#
#                                      GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 9408             Southern Baptist Convention  760385.0   1915.0        1
# 9412  The United Methodist Church, old count  250240.0   1354.0        2
# 9387                         Catholic Church   95096.0    158.0        3
# 9399                      Churches of Christ   34148.0    347.0        1
#
#       FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 9408    96.0         0         0         3
# 9412    92.0         0         0         0
# 9387    87.0         0         0         2
# 9399   115.0         0         0         0

# %%
#North Carolina, NC:
df_NC = df[df.STATEAB == 'NC']
df_NC
#For 2010-
df_NC_2010 = df_NC[df_NC.YEAR == 2010]
df_NC_2010_2 = df_NC_2010[df_NC_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_NC_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 10210     37      NC  2010  9535483     419
# 10240     37      NC  2010  9535483     449
# 10261     37      NC  2010  9535483     081
# 10296     37      NC  2010  9535483     300
# 10221     37      NC  2010  9535483     167
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 10210             Southern Baptist Convention  1513059.0   4241.0        1
# 10240  The United Methodist Church, old count   641971.0   1923.0        2
# 10261                         Catholic Church   392912.0    189.0        3
# 10296  National Baptist Convention, USA, Inc.    48281.0    105.0        6
# 10221                      Churches of Christ    24248.0    197.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 10210    96.0         0         0         3
# 10240    92.0         0         0         0
# 10261    87.0         0         0         2
# 10296    96.0         0         0         0
# ...

# %%
#For 2000-
df_NC_2000 = df_NC[df_NC.YEAR == 2000]
df_NC_2000_2 = df_NC_2000[df_NC_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_NC_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 10141     37      NC  2000  8049313     419
# 10161     37      NC  2000  8049313     449
# 10112     37      NC  2000  8049313     081
# 10174     37      NC  2000  8049313     167
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 10141             Southern Baptist Convention  1512058.0   3717.0        1
# 10161  The United Methodist Church, old count   638785.0   1964.0        2
# 10112                         Catholic Church   315606.0    180.0        3
# 10174                      Churches of Christ    21522.0    189.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 10141    96.0         0         0         3
# 10161    92.0         0         0         0
# 10112    87.0         0         0         2
# 10174   115.0         0         0         0

# %%
#For 1990-
df_NC_1990 = df_NC[df_NC.YEAR == 1990]
df_NC_1990_2 = df_NC_1990[df_NC_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_NC_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 10020     37      NC  1990  6628637     419
# 10048     37      NC  1990  6628637     449
# 10046     37      NC  1990  6628637     497
# 10014     37      NC  1990  6628637     081
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 10020             Southern Baptist Convention  1446228.0   3527.0        1
# 10048  The United Methodist Church, old count   605362.0   1983.0        2
# 10046                 Black Baptists Estimate   462785.0      0.0        6
# 10014                         Catholic Church   149483.0    175.0        3
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 10020    96.0         0         0         3
# 10048    92.0         0         0         0
# 10046    96.0         0         0         0
# 10014    87.0         0         0         2

# %%
#For 1980
df_NC_1980 = df_NC[df_NC.YEAR == 1980]
df_NC_1980_2 = df_NC_1980[df_NC_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_NC_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 9983      37      NC  1980  5881766     419
# 9963      37      NC  1980  5881766     449
# 9990      37      NC  1980  5881766     081
# 10004     37      NC  1980  5881766     167
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 9983              Southern Baptist Convention  1341047.0   3460.0        1
# 9963   The United Methodist Church, old count   592967.0   2016.0        2
# 9990                          Catholic Church    94768.0    155.0        3
# 10004                      Churches of Christ    14212.0    160.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 9983     96.0         0         0         3
# 9963     92.0         0         0         0
# 9990     87.0         0         0         2
# 10004   115.0         0         0         0

# %%
#Oklahoma, OK:
df_OK = df[df.STATEAB == 'OK']
df_OK
#For 2010-
df_OK_2010 = df_OK[df_OK.YEAR == 2010]
df_OK_2010_2 = df_OK_2010[df_OK_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_OK_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 13440     40      OK  2010  3751351     419
# 13480     40      OK  2010  3751351     449
# 13392     40      OK  2010  3751351     081
# 13375     40      OK  2010  3751351     167
# 13433     40      OK  2010  3751351     300
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 13440             Southern Baptist Convention  886394.0   1829.0        1
# 13480  The United Methodist Church, old count  300510.0    598.0        2
# 13392                         Catholic Church  178430.0    190.0        3
# 13375                      Churches of Christ   77495.0    583.0        1
# 13433  National Baptist Convention, USA, Inc.   19748.0     42.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 13440    96.0         0         0         3
# 13480    92.0         0         0         0
# 13392    87.0         0         0         2
# 13375   115.0         0         0         0
# ...

# %%
#For 2000-
df_OK_2000 = df_OK[df_OK.YEAR == 2000]
df_OK_2000_2 = df_OK_2000[df_OK_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_OK_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 13303     40      OK  2000  3450654     419
# 13368     40      OK  2000  3450654     449
# 13350     40      OK  2000  3450654     081
# 13324     40      OK  2000  3450654     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 13303             Southern Baptist Convention  967223.0   1578.0        1
# 13368  The United Methodist Church, old count  322794.0    636.0        2
# 13350                         Catholic Church  168625.0    195.0        3
# 13324                      Churches of Christ   83047.0    603.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 13303    96.0         0         0         3
# 13368    92.0         0         0         0
# 13350    87.0         0         0         2
# 13324   115.0         0         0         0

# %%
#For 1990-
df_OK_1990 = df_OK[df_OK.YEAR == 1990]
df_OK_1990_2 = df_OK_1990[df_OK_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_OK_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 13205     40      OK  1990  3145585     419
# 13216     40      OK  1990  3145585     449
# 13266     40      OK  1990  3145585     081
# 13269     40      OK  1990  3145585     497
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 13205             Southern Baptist Convention  964615.0   1490.0        1
# 13216  The United Methodist Church, old count  326294.0    681.0        2
# 13266                         Catholic Church  143640.0    201.0        3
# 13269                 Black Baptists Estimate   83619.0      0.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 13205    96.0         0         0         3
# 13216    92.0         0         0         0
# 13266    87.0         0         0         2
# 13269    96.0         0         0         0

# %%
#For 1980
df_OK_1980 = df_OK[df_OK.YEAR == 1980]
df_OK_1980_2 = df_OK_1980[df_OK_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_OK_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 13171     40      OK  1980  3025290     419
# 13149     40      OK  1980  3025290     449
# 13165     40      OK  1980  3025290     081
# 13148     40      OK  1980  3025290     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 13171             Southern Baptist Convention  799357.0   1422.0        1
# 13149  The United Methodist Church, old count  313466.0    698.0        2
# 13165                         Catholic Church  109197.0    196.0        3
# 13148                      Churches of Christ   91606.0    638.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 13171    96.0         0         0         3
# 13149    92.0         0         0         0
# 13165    87.0         0         0         2
# 13148   115.0         0         0         0

# %%
#South Carolina, SC:
df_SC = df[df.STATEAB == 'SC']
df_SC
#For 2010-
df_SC_2010 = df_SC[df_SC.YEAR == 2010]
df_SC_2010_2 = df_SC_2010[df_SC_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_SC_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 14890     45      SC  2010  4625364     419
# 14932     45      SC  2010  4625364     449
# 14856     45      SC  2010  4625364     081
# 14861     45      SC  2010  4625364     300
# 14854     45      SC  2010  4625364     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 14890             Southern Baptist Convention  913763.0   2110.0        1
# 14932  The United Methodist Church, old count  288378.0   1016.0        2
# 14856                         Catholic Church  181743.0    119.0        3
# 14861  National Baptist Convention, USA, Inc.   64925.0    185.0        6
# 14854                      Churches of Christ   13816.0    127.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 14890    96.0         0         0         3
# 14932    92.0         0         0         0
# 14856    87.0         0         0         2
# 14861    96.0         0         0         0
# ...

# %%
#For 2000-
df_SC_2000 = df_SC[df_SC.YEAR == 2000]
df_SC_2000_2 = df_SC_2000[df_SC_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_SC_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 14798     45      SC  2000  4012012     419
# 14835     45      SC  2000  4012012     449
# 14790     45      SC  2000  4012012     081
# 14813     45      SC  2000  4012012     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 14798             Southern Baptist Convention  928341.0   1878.0        1
# 14835  The United Methodist Church, old count  302528.0   1047.0        2
# 14790                         Catholic Church  136719.0    118.0        3
# 14813                      Churches of Christ   13091.0    118.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 14798    96.0         0         0         3
# 14835    92.0         0         0         0
# 14790    87.0         0         0         2
# 14813   115.0         0         0         0

# %%
#For 1990-
df_SC_1990 = df_SC[df_SC.YEAR == 1990]
df_SC_1990_2 = df_SC_1990[df_SC_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_SC_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 14749     45      SC  1990  3486703     419
# 14759     45      SC  1990  3486703     497
# 14708     45      SC  1990  3486703     449
# 14747     45      SC  1990  3486703     081
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 14749             Southern Baptist Convention  894390.0   1781.0        1
# 14759                 Black Baptists Estimate  345858.0      0.0        6
# 14708  The United Methodist Church, old count  308915.0   1074.0        2
# 14747                         Catholic Church   78768.0    120.0        3
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 14749    96.0         0         0         3
# 14759    96.0         0         0         0
# 14708    92.0         0         0         0
# 14747    87.0         0         0         2

# %%
#For 1980
df_SC_1980 = df_SC[df_SC.YEAR == 1980]
df_SC_1980_2 = df_SC_1980[df_SC_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_SC_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 14690     45      SC  1980  3121820     419
# 14685     45      SC  1980  3121820     449
# 14693     45      SC  1980  3121820     081
# 14697     45      SC  1980  3121820     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 14690             Southern Baptist Convention  802152.0   1674.0        1
# 14685  The United Methodist Church, old count  294818.0   1089.0        2
# 14693                         Catholic Church   59027.0    112.0        3
# 14697                      Churches of Christ    8680.0     95.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 14690    96.0         0         0         3
# 14685    92.0         0         0         0
# 14693    87.0         0         0         2
# 14697   115.0         0         0         0

# %%
#Tennessee, TN:
df_TN = df[df.STATEAB == 'TN']
df_TN
#For 2010-
df_TN_2010 = df_TN[df_TN.YEAR == 2010]
df_TN_2010_2 = df_TN_2010[df_TN_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_TN_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 15504     47      TN  2010  6346105     419
# 15624     47      TN  2010  6346105     449
# 15512     47      TN  2010  6346105     081
# 15507     47      TN  2010  6346105     167
# 15571     47      TN  2010  6346105     300
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15504             Southern Baptist Convention  1483356.0   3189.0        1
# 15624  The United Methodist Church, old count   387409.0   1508.0        2
# 15512                         Catholic Church   222343.0    151.0        3
# 15507                      Churches of Christ   214118.0   1432.0        1
# 15571  National Baptist Convention, USA, Inc.   125748.0    211.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15504    96.0         0         0         3
# 15624    92.0         0         0         0
# 15512    87.0         0         0         2
# 15507   115.0         0         0         0
# ...

# %%
#For 2000-
df_TN_2000 = df_TN[df_TN.YEAR == 2000]
df_TN_2000_2 = df_TN_2000[df_TN_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_TN_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 15432     47      TN  2000  5689283     419
# 15470     47      TN  2000  5689283     449
# 15439     47      TN  2000  5689283     167
# 15418     47      TN  2000  5689283     081
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15432             Southern Baptist Convention  1414199.0   2972.0        1
# 15470  The United Methodist Church, old count   393994.0   1577.0        2
# 15439                      Churches of Christ   216648.0   1466.0        1
# 15418                         Catholic Church   183161.0    152.0        3
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15432    96.0         0         0         3
# 15470    92.0         0         0         0
# 15439   115.0         0         0         0
# 15418    87.0         0         0         2

# %%
#For 1990-
df_TN_1990 = df_TN[df_TN.YEAR == 1990]
df_TN_1990_2 = df_TN_1990[df_TN_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_TN_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 15352     47      TN  1990  4877185     419
# 15344     47      TN  1990  4877185     449
# 15359     47      TN  1990  4877185     497
# 15356     47      TN  1990  4877185     081
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15352             Southern Baptist Convention  1343312.0   2801.0        1
# 15344  The United Methodist Church, old count   396862.0   1675.0        2
# 15359                 Black Baptists Estimate   250490.0      0.0        6
# 15356                         Catholic Church   137203.0    142.0        3
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15352    96.0         0         0         3
# 15344    92.0         0         0         0
# 15359    96.0         0         0         0
# 15356    87.0         0         0         2

# %%
#For 1980
df_TN_1980 = df_TN[df_TN.YEAR == 1980]
df_TN_1980_2 = df_TN_1980[df_TN_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_TN_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 15290     47      TN  1980  4591120     419
# 15289     47      TN  1980  4591120     449
# 15316     47      TN  1980  4591120     167
# 15310     47      TN  1980  4591120     081
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15290             Southern Baptist Convention  1203537.0   2754.0        1
# 15289  The United Methodist Church, old count   413149.0   1738.0        2
# 15316                      Churches of Christ   226320.0   1444.0        1
# 15310                         Catholic Church   114916.0    128.0        3
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15290    96.0         0         0         3
# 15289    92.0         0         0         0
# 15316   115.0         0         0         0
# 15310    87.0         0         0         2

# %%
#Texas, TX:
df_TX = df[df.STATEAB == 'TX']
df_TX
#For 2010-
df_TX_2010 = df_TX[df_TX.YEAR == 2010]
df_TX_2010_2 = df_TX_2010[df_TX_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_TX_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 15994     48      TX  2010  25145561     081
# 15909     48      TX  2010  25145561     419
# 15979     48      TX  2010  25145561     449
# 16040     48      TX  2010  25145561     167
# 15934     48      TX  2010  25145561     300
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15994                         Catholic Church  4673500.0   1348.0        3
# 15909             Southern Baptist Convention  3721318.0   8133.0        1
# 15979  The United Methodist Church, old count  1017388.0   1967.0        2
# 16040                      Churches of Christ   351129.0   2042.0        1
# 15934  National Baptist Convention, USA, Inc.    59529.0    133.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15994    87.0         0         0         2
# 15909    96.0         0         0         3
# 15979    92.0         0         0         0
# 16040   115.0         0         0         0
# ...

# %%
#For 2000-
df_TX_2000 = df_TX[df_TX.YEAR == 2000]
df_TX_2000_2 = df_TX_2000[df_TX_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_TX_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 15899     48      TX  2000  20851753     081
# 15852     48      TX  2000  20851753     419
# 15908     48      TX  2000  20851753     449
# 15880     48      TX  2000  20851753     167
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15899                         Catholic Church  4368969.0   1293.0        3
# 15852             Southern Baptist Convention  3519459.0   4973.0        1
# 15908  The United Methodist Church, old count  1022342.0   2110.0        2
# 15880                      Churches of Christ   377264.0   2188.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15899    87.0         0         0         2
# 15852    96.0         0         0         3
# 15908    92.0         0         0         0
# 15880   115.0         0         0         0

# %%
#For 1990-
df_TX_1990 = df_TX[df_TX.YEAR == 1990]
df_TX_1990_2 = df_TX_1990[df_TX_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_TX_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 15757     48      TX  1990  16986510     081
# 15732     48      TX  1990  16986510     419
# 15761     48      TX  1990  16986510     449
# 15747     48      TX  1990  16986510     497
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15757                         Catholic Church  3574728.0   1290.0        3
# 15732             Southern Baptist Convention  3259395.0   4285.0        1
# 15761  The United Methodist Church, old count  1004318.0   2186.0        2
# 15747                 Black Baptists Estimate   815771.0      0.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15757    87.0         0         0         2
# 15732    96.0         0         0         3
# 15761    92.0         0         0         0
# 15747    96.0         0         0         0

# %%
#For 1980
df_TX_1980 = df_TX[df_TX.YEAR == 1980]
df_TX_1980_2 = df_TX_1980[df_TX_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_TX_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 15687     48      TX  1980  14229191     419
# 15679     48      TX  1980  14229191     081
# 15653     48      TX  1980  14229191     449
# 15669     48      TX  1980  14229191     167
#
#                                       GRPNAME   ADHERENT  CONGREG  RELTRAD  \
# 15687             Southern Baptist Convention  2659894.0   3896.0        1
# 15679                         Catholic Church  2340162.0   1227.0        3
# 15653  The United Methodist Church, old count   932488.0   2257.0        2
# 15669                      Churches of Christ   355396.0   2222.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 15687    96.0         0         0         3
# 15679    87.0         0         0         2
# 15653    92.0         0         0         0
# 15669   115.0         0         0         0

# %%
#Virginia, VA: 
df_VA = df[df.STATEAB == 'VA']
df_VA
#For 2010-
df_VA_2010 = df_VA[df_VA.YEAR == 2010]
df_VA_2010_2 = df_VA_2010[df_VA_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_VA_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 16566     51      VA  2010  8001024     419
# 16565     51      VA  2010  8001024     081
# 16676     51      VA  2010  8001024     449
# 16697     51      VA  2010  8001024     300
# 16672     51      VA  2010  8001024     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 16566             Southern Baptist Convention  763655.0   1914.0        1
# 16565                         Catholic Church  673853.0    230.0        3
# 16676  The United Methodist Church, old count  450771.0   1540.0        2
# 16697  National Baptist Convention, USA, Inc.   56554.0     74.0        6
# 16672                      Churches of Christ   16591.0    165.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 16566    96.0         0         0         3
# 16565    87.0         0         0         2
# 16676    92.0         0         0         0
# 16697    96.0         0         0         0
# ...

# %%
#For 2000-
df_VA_2000 = df_VA[df_VA.YEAR == 2000]
df_VA_2000_2 = df_VA_2000[df_VA_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_VA_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 16495     51      VA  2000  7078515     419
# 16548     51      VA  2000  7078515     081
# 16489     51      VA  2000  7078515     449
# 16509     51      VA  2000  7078515     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 16495             Southern Baptist Convention  774637.0   1660.0        1
# 16548                         Catholic Church  606059.0    233.0        3
# 16489  The United Methodist Church, old count  470381.0   1601.0        2
# 16509                      Churches of Christ   16375.0    162.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 16495    96.0         0         0         3
# 16548    87.0         0         0         2
# 16489    92.0         0         0         0
# 16509   115.0         0         0         0

# %%
#For 1990-
df_VA_1990 = df_VA[df_VA.YEAR == 1990]
df_VA_1990_2 = df_VA_1990[df_VA_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_VA_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 16375     51      VA  1990  6187358     419
# 16379     51      VA  1990  6187358     449
# 16439     51      VA  1990  6187358     081
# 16412     51      VA  1990  6187358     497
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 16375             Southern Baptist Convention  742860.0   1515.0        1
# 16379  The United Methodist Church, old count  490789.0   1626.0        2
# 16439                         Catholic Church  384285.0    228.0        3
# 16412                 Black Baptists Estimate  373756.0      0.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 16375    96.0         0         0         3
# 16379    92.0         0         0         0
# 16439    87.0         0         0         2
# 16412    96.0         0         0         0

# %%
#For 1980
df_VA_1980 = df_VA[df_VA.YEAR == 1980]
df_VA_1980_2 = df_VA_1980[df_VA_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_VA_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 16319     51      VA  1980  5346818     419
# 16355     51      VA  1980  5346818     449
# 16350     51      VA  1980  5346818     081
# 16341     51      VA  1980  5346818     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 16319             Southern Baptist Convention  690276.0   1431.0        1
# 16355  The United Methodist Church, old count  501217.0   1688.0        2
# 16350                         Catholic Church  284389.0    186.0        3
# 16341                      Churches of Christ   14201.0    130.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 16319    96.0         0         0         3
# 16355    92.0         0         0         0
# 16350    87.0         0         0         2
# 16341   115.0         0         0         0

# %%
#West Virginia, WV:
df_WV = df[df.STATEAB == 'WV']
df_WV
#For 2010-
df_WV_2010 = df_WV[df_WV.YEAR == 2010]
df_WV_2010_2 = df_WV_2010[df_WV_2010['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','National Baptist Convention, USA, Inc.'])]
df_WV_2010_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 18068     54      WV  2010  1852994     449
# 18073     54      WV  2010  1852994     081
# 18017     54      WV  2010  1852994     419
# 17993     54      WV  2010  1852994     167
# 17972     54      WV  2010  1852994     300
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 18068  The United Methodist Church, old count  130990.0   1197.0        2
# 18073                         Catholic Church   95849.0    139.0        3
# 18017             Southern Baptist Convention   42834.0    232.0        1
# 17993                      Churches of Christ   22167.0    287.0        1
# 17972  National Baptist Convention, USA, Inc.    5341.0     22.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 18068    92.0         0         0         0
# 18073    87.0         0         0         2
# 18017    96.0         0         0         3
# 17993   115.0         0         0         0
# ...

# %%
#For 2000-
df_WV_2000 = df_WV[df_WV.YEAR == 2000]
df_WV_2000_2 = df_WV_2000[df_WV_2000['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_WV_2000_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 17964     54      WV  2000  1808344     449
# 17920     54      WV  2000  1808344     081
# 17915     54      WV  2000  1808344     419
# 17902     54      WV  2000  1808344     167
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 17964  The United Methodist Church, old count  150985.0   1341.0        2
# 17920                         Catholic Church  105363.0    149.0        3
# 17915             Southern Baptist Convention   43606.0    165.0        1
# 17902                      Churches of Christ   24143.0    294.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 17964    92.0         0         0         0
# 17920    87.0         0         0         2
# 17915    96.0         0         0         3
# 17902   115.0         0         0         0

# %%
#For 1990-
df_WV_1990 = df_WV[df_WV.YEAR == 1990]
df_WV_1990_2 = df_WV_1990[df_WV_1990['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Black Baptists Estimate','Presbyterian Church (U.S.A.)'])]
df_WV_1990_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 17850     54      WV  1990  1793477     449
# 17882     54      WV  1990  1793477     081
# 17887     54      WV  1990  1793477     419
# 17852     54      WV  1990  1793477     497
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 17850  The United Methodist Church, old count  182731.0   1458.0        2
# 17882                         Catholic Church  108529.0    177.0        3
# 17887             Southern Baptist Convention   43161.0    135.0        1
# 17852                 Black Baptists Estimate   17586.0      0.0        6
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 17850    92.0         0         0         0
# 17882    87.0         0         0         2
# 17887    96.0         0         0         3
# 17852    96.0         0         0         0

# %%
#For 1980
df_WV_1980 = df_WV[df_WV.YEAR == 1980]
df_WV_1980_2 = df_WV_1980[df_WV_1980['GRPNAME'].isin(['Catholic Church','Southern Baptist Convention', 'The United Methodist Church, old count','Churches of Christ','Presbyterian Church (U.S.A.)'])]
df_WV_1980_2.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR   TOTPOP GRPCODE  \
# 17808     54      WV  1980  1949644     449
# 17810     54      WV  1980  1949644     081
# 17762     54      WV  1980  1949644     167
# 17775     54      WV  1980  1949644     419
#
#                                       GRPNAME  ADHERENT  CONGREG  RELTRAD  \
# 17808  The United Methodist Church, old count  219560.0   1584.0        2
# 17810                         Catholic Church  105346.0    175.0        3
# 17762                      Churches of Christ   30473.0    276.0        1
# 17775             Southern Baptist Convention   29239.0     87.0        1
#
#        FAMILY  NOTE_MIS  NOTE_COM  NOTE_MEA
# 17808    92.0         0         0         0
# 17810    87.0         0         0         2
# 17762   115.0         0         0         0
# 17775    96.0         0         0         3

# %%
gdf = geopandas.GeoDataFrame(df)
gdf=gdf[~gdf['STATEAB'].str.contains("AK")]
gdf=gdf[~gdf['STATEAB'].str.contains("HI")]
gdf=gdf[~gdf['STATEAB'].str.contains("WA")]
gdf=gdf[~gdf['STATEAB'].str.contains("OR")]
gdf=gdf[~gdf['STATEAB'].str.contains("CA")]
gdf=gdf[~gdf['STATEAB'].str.contains("MT")]
gdf=gdf[~gdf['STATEAB'].str.contains("ID")]
gdf=gdf[~gdf['STATEAB'].str.contains("NV")]
gdf=gdf[~gdf['STATEAB'].str.contains("AZ")]
gdf=gdf[~gdf['STATEAB'].str.contains("UT")]
gdf=gdf[~gdf['STATEAB'].str.contains("WY")]
gdf=gdf[~gdf['STATEAB'].str.contains("ND")]
gdf=gdf[~gdf['STATEAB'].str.contains("SD")]
gdf=gdf[~gdf['STATEAB'].str.contains("NE")]
gdf=gdf[~gdf['STATEAB'].str.contains("KS")]
gdf=gdf[~gdf['STATEAB'].str.contains("MN")]
gdf=gdf[~gdf['STATEAB'].str.contains("NM")]
gdf=gdf[~gdf['STATEAB'].str.contains("CO")]
gdf=gdf[~gdf['STATEAB'].str.contains("MN")]
gdf=gdf[~gdf['STATEAB'].str.contains("IA")]
gdf=gdf[~gdf['STATEAB'].str.contains("OH")]
gdf=gdf[~gdf['STATEAB'].str.contains("IL")]
gdf=gdf[~gdf['STATEAB'].str.contains("WI")]
gdf=gdf[~gdf['STATEAB'].str.contains("MI")]
gdf=gdf[~gdf['STATEAB'].str.contains("PA")]
gdf=gdf[~gdf['STATEAB'].str.contains("NJ")]
gdf=gdf[~gdf['STATEAB'].str.contains("CT")]
gdf=gdf[~gdf['STATEAB'].str.contains("RI")]
gdf=gdf[~gdf['STATEAB'].str.contains("MA")]
gdf=gdf[~gdf['STATEAB'].str.contains("NY")]
gdf=gdf[~gdf['STATEAB'].str.contains("VT")]
gdf=gdf[~gdf['STATEAB'].str.contains("NH")]
gdf=gdf[~gdf['STATEAB'].str.contains("ME")]
gdf=gdf[~gdf['STATEAB'].str.contains("MO")]
gdf=gdf[~gdf['STATEAB'].str.contains("IN")]

gdf=gdf[gdf['GRPNAME'].isin(['Catholic Church','The United Methodist Church, old count','Southern Baptist Convention'])]
gdf = gdf[gdf.YEAR == 2010]
gdf.sort_values(by ='ADHERENT', ascending=False)
# Out:
#        STFIP STATEAB  YEAR    TOTPOP GRPCODE  \
# 15994     48      TX  2010  25145561     081
# 15909     48      TX  2010  25145561     419
# 3449      12      FL  2010  18801310     081
# 3915      13      GA  2010   9687653     419
# 10210     37      NC  2010   9535483     419
# 15504     47      TN  2010   6346105     419
# 583        1      AL  2010   4779736     419
# 3421      12      FL  2010  18801310     419
# 6917      22      LA  2010   4533372     081
# 15979     48      TX  2010  25145561     449
# 6629      21      KY  2010   4339367     419
# 14890     45      SC  2010   4625364     419
# 9563      28      MS  2010   2967297     419
# 13440     40      OK  2010   3751351     419
# 7667      24      MD  2010   5773552     081
# 16566     51      VA  2010   8001024     419
# 6941      22      LA  2010   4533372     419
# 16565     51      VA  2010   8001024     081
# 879        5      AR  2010   2915918     419
# 10240     37      NC  2010   9535483     449
# ...

# %%
usa = geopandas.read_file('../data/s_22mr22.shp')

# %%
usa=usa[~usa['STATE'].astype(str).str.contains("WA")]
usa=usa[~usa['STATE'].astype(str).str.contains("OR")]
usa=usa[~usa['STATE'].astype(str).str.contains("CA")]
usa=usa[~usa['STATE'].astype(str).str.contains("MT")]
usa=usa[~usa['STATE'].astype(str).str.contains("ID")]
usa=usa[~usa['STATE'].astype(str).str.contains("NV")]
usa=usa[~usa['STATE'].astype(str).str.contains("AZ")]
usa=usa[~usa['STATE'].astype(str).str.contains("UT")]
usa=usa[~usa['STATE'].astype(str).str.contains("WY")]
usa=usa[~usa['STATE'].astype(str).str.contains("ND")]
usa=usa[~usa['STATE'].astype(str).str.contains("SD")]
usa=usa[~usa['STATE'].astype(str).str.contains("NE")]
usa=usa[~usa['STATE'].astype(str).str.contains("KS")]
usa=usa[~usa['STATE'].astype(str).str.contains("MN")]
usa=usa[~usa['STATE'].astype(str).str.contains("NM")]
usa=usa[~usa['STATE'].astype(str).str.contains("CO")]
usa=usa[~usa['STATE'].astype(str).str.contains("MN")]
usa=usa[~usa['STATE'].astype(str).str.contains("IA")]
usa=usa[~usa['STATE'].astype(str).str.contains("OH")]
usa=usa[~usa['STATE'].astype(str).str.contains("IL")]
usa=usa[~usa['STATE'].astype(str).str.contains("WI")]
usa=usa[~usa['STATE'].astype(str).str.contains("MI")]
usa=usa[~usa['STATE'].astype(str).str.contains("PA")]
usa=usa[~usa['STATE'].astype(str).str.contains("NJ")]
usa=usa[~usa['STATE'].astype(str).str.contains("CT")]
usa=usa[~usa['STATE'].astype(str).str.contains("RI")]
usa=usa[~usa['STATE'].astype(str).str.contains("MA")]
usa=usa[~usa['STATE'].astype(str).str.contains("NY")]
usa=usa[~usa['STATE'].astype(str).str.contains("VT")]
usa=usa[~usa['STATE'].astype(str).str.contains("NH")]
usa=usa[~usa['STATE'].astype(str).str.contains("ME")]
usa=usa[~usa['STATE'].astype(str).str.contains("MO")]
usa=usa[~usa['STATE'].astype(str).str.contains("IN")]
usa=usa[~usa['STATE'].astype(str).str.contains("GU")]
usa=usa[~usa['STATE'].astype(str).str.contains("MP")]
usa=usa[~usa['STATE'].astype(str).str.contains("PW")]
usa=usa[~usa['STATE'].astype(str).str.contains("FM")]
usa=usa[~usa['STATE'].astype(str).str.contains("MH")]
usa=usa[~usa['STATE'].astype(str).str.contains("AS")]
usa=usa[~usa['STATE'].astype(str).str.contains("VI")]
usa=usa[~usa['STATE'].astype(str).str.contains("HI")]
usa=usa[~usa['STATE'].astype(str).str.contains("AK")]
usa=usa[~usa['STATE'].astype(str).str.contains("PR")]

usa.plot();

# %%
df_merged = gdf.merge(usa , left_on = "STATEAB" , right_on = "STATE")

# %%
df_merged=df_merged.drop("CONGREG",axis=1)
df_merged=df_merged.drop("RELTRAD",axis=1)
df_merged=df_merged.drop("FAMILY",axis=1)
df_merged=df_merged.drop("NOTE_COM",axis=1)
df_merged=df_merged.drop("NOTE_MEA",axis=1)
df_merged=df_merged.drop("GRPCODE",axis=1)
df_merged=df_merged[~df_merged['YEAR'].astype(str).str.contains("1980")]
df_merged=df_merged[~df_merged['YEAR'].astype(str).str.contains("1990")]
df_merged=df_merged[~df_merged['YEAR'].astype(str).str.contains("2000")]
df_merged=df_merged.drop("STFIP",axis=1)
df_merged=df_merged.drop("NOTE_MIS",axis=1)
df_merged=df_merged.drop("STATEAB",axis=1)
df_merged=df_merged.drop("TOTPOP",axis=1)
df_merged=df_merged.drop("FIPS",axis=1)
df_merged=df_merged.drop("LON",axis=1)
df_merged=df_merged.drop("LAT",axis=1)
df_merged=df_merged.drop("YEAR",axis=1)

# %%
gdf_merged = geopandas.GeoDataFrame(df_merged)

# %%
gdf_merged['ADHERENT'] = gdf_merged.ADHERENT

# %%
gdf_merged.plot('ADHERENT',legend=True);

# %%
#gdf_merged.explore('ADHERENT', legend=False)

# %%
plot = gdf_merged[['STATE','ADHERENT']].plot(kind='bar',figsize=(10,10))
plot.set_xticklabels(gdf_merged['GRPNAME']);

# %%
plot = gdf_merged[['STATE','ADHERENT']].plot(kind='bar',figsize=(10,10))
plot.set_xticklabels(gdf_merged['STATE']);
