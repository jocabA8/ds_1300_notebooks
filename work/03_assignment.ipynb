# %% [markdown]
# # Linear Regression and Temperature

# %% [markdown]
# In this notebook, we'll look at using linear regression to study changes in temperature.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# ## Getting our data

# %% [markdown]
# We'll be getting data from [North America Land Data Assimilation System (NLDAS)](https://wonder.cdc.gov/NASA-NLDAS.html), which provides the daily average temperature from 1979-2011 for the United States.

# %% [markdown]
# For the next step, you will need to choose some settings in the data request form. These are:
#
# - GroupBy: Month Day, Year
# - Your State
# - Export Results (check box)
# - Show Zero Values (check box)

# %% [markdown]
# >1) Download the data for your home state (or state of your choosing) and upload it to M2 in your work directory.

# %% [markdown]
# # Loading our data

# %%
df = pd.read_csv('North America Land Data Assimilation System (NLDAS) Daily Air Temperatures and Heat Index (1979-2011).txt',delimiter='\t',skipfooter=14,engine='python')

# %%
df
# Out:
#        Notes Month Day, Year Month Day, Year Code  \
# 0        NaN    Jan 01, 1979           1979/01/01
# 1        NaN    Jan 02, 1979           1979/01/02
# 2        NaN    Jan 03, 1979           1979/01/03
# 3        NaN    Jan 04, 1979           1979/01/04
# 4        NaN    Jan 05, 1979           1979/01/05
# ...      ...             ...                  ...
# 12049    NaN    Dec 28, 2011           2011/12/28
# 12050    NaN    Dec 29, 2011           2011/12/29
# 12051    NaN    Dec 30, 2011           2011/12/30
# 12052    NaN    Dec 31, 2011           2011/12/31
# 12053  Total             NaN                  NaN
#
#        Avg Daily Max Air Temperature (F)
# 0                                  29.03
# 1                                  31.35
# 2                                  41.66
# 3                                  47.30
# 4                                  46.89
# ...                                  ...
# 12049                              59.91
# ...

# %% [markdown]
# ### Clean the data

# %% [markdown]
# >2) Drop any rows that have the value "Total" in the Notes column, then drop the Notes column

# %%
df=df[~df['Notes'].astype(str).str.contains("Total")]

# %%
df=df.drop("Notes",axis=1)

# %% [markdown]
# >3) Make a column called Date that is in the pandas datetime format

# %%
df['Date'] = pd.to_datetime(df['Month Day, Year'], errors= 'raise')

# %% [markdown]
# >4) Make columns for 'Year', 'Month', and 'Day' by splitting the column 'Month Day, Year'

# %%
df['Day'] = df['Date'].map(lambda x: x.day)
df['Month'] = df['Date'].map(lambda x: x.month)
df['Year'] = df['Date'].map(lambda x: x.year)
df
# Out:
#       Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 0        Jan 01, 1979           1979/01/01                              29.03
# 1        Jan 02, 1979           1979/01/02                              31.35
# 2        Jan 03, 1979           1979/01/03                              41.66
# 3        Jan 04, 1979           1979/01/04                              47.30
# 4        Jan 05, 1979           1979/01/05                              46.89
# ...               ...                  ...                                ...
# 12048    Dec 27, 2011           2011/12/27                              56.67
# 12049    Dec 28, 2011           2011/12/28                              59.91
# 12050    Dec 29, 2011           2011/12/29                              66.64
# 12051    Dec 30, 2011           2011/12/30                              68.61
# 12052    Dec 31, 2011           2011/12/31                              73.49
#
# ...

# %%
df['DateInt'] = df['Date'].astype(int)/10e10 # This will be used later
df.head(5)
# Out:
#   Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 0    Jan 01, 1979           1979/01/01                              29.03
# 1    Jan 02, 1979           1979/01/02                              31.35
# 2    Jan 03, 1979           1979/01/03                              41.66
# 3    Jan 04, 1979           1979/01/04                              47.30
# 4    Jan 05, 1979           1979/01/05                              46.89
#
#         Date  Day  Month  Year    DateInt
# 0 1979-01-01    1      1  1979  2839968.0
# 1 1979-01-02    2      1  1979  2840832.0
# 2 1979-01-03    3      1  1979  2841696.0
# 3 1979-01-04    4      1  1979  2842560.0
# 4 1979-01-05    5      1  1979  2843424.0

# %% [markdown]
# ## Generating a scatter plot

# %% [markdown]
# > 4) Use df.plot.scatter to plot 'Date' vs 'Avg Daily Max Air Temperature (F)'. You might want to add figsize=(50,5) as an argument to make it more clear what is happening.

# %%
df.plot.scatter('DateInt', 'Avg Daily Max Air Temperature (F)', figsize=(50,5));

# %% [markdown]
# >5) Describe your plot.

# %%
#The plot shows a relatively volatile temperature throughout the year, with it having spikes up and then back down, and vice versa

# %% [markdown]
# ### Adding colors for our graph

# %%
# No need to edit this unless you want to try different colors or a pattern other than colors by month

cmap = matplotlib.cm.get_cmap("nipy_spectral", len(df['Month'].unique())) # Builds a discrete color mapping using a built in matplotlib color map

c = []
for i in range(cmap.N): # Converts our discrete map into Hex Values
    rgba = cmap(i)
    c.append(matplotlib.colors.rgb2hex(rgba))

df['color']=[c[int(i-1)] for i in df['Month'].astype(int)] # Adds a column to our dataframe with the color we want for each row

# %% [markdown]
# >6) Make the same plot as 4) but add color by adding the argument c=df\['color'\] to our plotting command.

# %%
plot_DF = df.plot.scatter(x='DateInt',y='Avg Daily Max Air Temperature (F)', c=df['color'],figsize=(50,5))
plot_DF.set_title("Average Daily Max Air Temperature of Texas (1979-2011)")
plt.show()

# %% [markdown]
# ## Pick a subset of the data

# %% [markdown]
# >7) Select a 6 month period from the data. # Hint use logic and pd.datetime(YYYY, MM, DD)

# %%
df['Month'] = df['Month'].apply(lambda x: int(x))
df['Year'] = df['Year'].apply(lambda x: int(x))
df_2010 = df.loc[df['Year'] == 2010]
df_2010_6 = df_2010.loc[df['Month'] <= 6]
df_2010
# Out:
#       Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 11323    Jan 01, 2010           2010/01/01                              50.75
# 11324    Jan 02, 2010           2010/01/02                              51.86
# 11325    Jan 03, 2010           2010/01/03                              50.94
# 11326    Jan 04, 2010           2010/01/04                              45.27
# 11327    Jan 05, 2010           2010/01/05                              48.39
# ...               ...                  ...                                ...
# 11683    Dec 27, 2010           2010/12/27                              56.82
# 11684    Dec 28, 2010           2010/12/28                              59.43
# 11685    Dec 29, 2010           2010/12/29                              67.01
# 11686    Dec 30, 2010           2010/12/30                              71.88
# 11687    Dec 31, 2010           2010/12/31                              66.24
#
# ...

# %% [markdown]
# >8) Plot the subset using the the same code you used in 6). You can change the figsize if needed.

# %%
plot_DF2010 = df_2010_6.plot.scatter(x='DateInt',y='Avg Daily Max Air Temperature (F)', c=df_2010_6['color'])
plot_DF2010.set_title("Average Daily Max Air Temperature of Texas (Jan-Jun 2011)")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# We are going to use a very [simple linear regression model](https://en.wikipedia.org/wiki/Simple_linear_regression). You may implement a more complex model if you wish.
#
# The method described here is called the least squares method and is defined as:
#
# $m = \frac{\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y}))}{\sum_{i=1}^{n}(x_i-\bar{x})^2}$
#
# $b = \bar{y} - m\bar{x}$
#
# Where $\bar{x}$ and $\bar{y}$ are the average value of $x$ and $y$ respectively.

# %% [markdown]
# First we need to define our X and Y values.

# %%
X=df_2010_6['DateInt'].values
Y=df_2010_6['Avg Daily Max Air Temperature (F)'].values

# %%
def lin_reg(x,y):
    # Calculate the average x and y
    x_avg = np.mean(x)
    y_avg = np.mean(y)

    num = 0
    den = 0
    for i in range(len(x)): # This represents our sums
        num = num + (x[i] - x_avg)*(y[i] - y_avg) # Our numerator
        den = den + (x[i] - x_avg)**2 # Our denominator
    # Calculate slope
    m = num / den
    # Calculate intercept
    b = y_avg - m*x_avg

    print (m, b)
    
    # Calculate our predicted y values
    y_pred = m*x + b
    
    return y_pred

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 0.0003508158934033703 -4381.798134296641

# %%
df_2010_6.plot.scatter(x='DateInt', y='Avg Daily Max Air Temperature (F)',c=df_2010_6['color'])
plt.plot([min(df_2010_6['DateInt'].values), max(df_2010_6['DateInt'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >9) What are the slope and intercept of your best fit line?

# %%
#Slope is 0.00035082 and the intercept is -4381.7981 of the best fit line

# %% [markdown]
# >10) What are the minimum and maximum Y values of your best fit line? Is your slope positive or negative?

# %%
#Slope is positive
print('Minimum Y value', min(Y_pred))
print("Maximum Y value", max(Y_pred))
# Out:
# Minimum Y value 46.564920769837954
# Maximum Y value 101.12380851193029

# %% [markdown]
# ## Putting it all together

# %% [markdown]
# >11) Generate a best fit line for the full data set and plot the line over top of the data.

# %%
X = df['DateInt'].values
Y = df['Avg Daily Max Air Temperature (F)'].values

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 3.072410840971274e-07 75.67019246681011

# %%
df.plot.scatter(x='DateInt', y='Avg Daily Max Air Temperature (F)', c=df['color'], figsize=(50,5))
plt.plot([min(df['DateInt'].values), max(df['DateInt'].values)], [min(Y_pred),max(Y_pred)],color='blue')
plt.show()

# %% [markdown]
# >12) Is the slope positive or negative? What do you think that means?

# %%
#Since the slope = 3.0724 is greater than zero the slope is positive, which means the the temperature is slightly rising
